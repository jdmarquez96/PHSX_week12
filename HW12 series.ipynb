# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel("IPEDS_data.xlsx")
df
# Out:
#       ID number                                               Name  year  \
# 0        100654                           Alabama A & M University  2013
# 1        100663                University of Alabama at Birmingham  2013
# 2        100690                                 Amridge University  2013
# 3        100706                University of Alabama in Huntsville  2013
# 4        100724                           Alabama State University  2013
# 5        100751                          The University of Alabama  2013
# 6        100812                            Athens State University  2013
# 7        100830                    Auburn University at Montgomery  2013
# 8        100858                                  Auburn University  2013
# 9        100937                        Birmingham Southern College  2013
# 10       101073                          Concordia College Alabama  2013
# 11       101189                                Faulkner University  2013
# ...

# %%
df.iloc[0:1, 0:100]
#df.iloc[0:3, 1:4]
# Out:
#    ID number                      Name  year ZIP code  \
# 0     100654  Alabama A & M University  2013    35762
#
#                    Highest degree offered     County name  \
# 0  Doctor's degree - research/scholarship  Madison County
#
#    Longitude location of institution  Latitude location of institution  \
# 0                         -86.568502                         34.783368
#
#   Religious affiliation Offers Less than one year certificate  \
# 0        Not applicable                            Implied no
#
#                      ...                      \
# 0                    ...
#
#   Percent of total enrollment that are Asian  \
# 0                                        1.0
#
#   Percent of total enrollment that are Black or African American  \
# 0                                               92.0
#
#   Percent of total enrollment that are Hispanic/Latino  \
# 0                                                1.0
#
# ...

# %%
s = df['Percent of total enrollment that are women']
name = df['Name']
name[0:20]
# Out:
# 0                Alabama A & M University
# 1     University of Alabama at Birmingham
# 2                      Amridge University
# 3     University of Alabama in Huntsville
# 4                Alabama State University
# 5               The University of Alabama
# 6                 Athens State University
# 7         Auburn University at Montgomery
# 8                       Auburn University
# 9             Birmingham Southern College
# 10              Concordia College Alabama
# 11                    Faulkner University
# 12                     Huntingdon College
# 13          Jacksonville State University
# 14                         Judson College
# 15             University of West Alabama
# 16                          Miles College
# 17                   University of Mobile
# 18               University of Montevallo
# 19            University of North Alabama
# Name: Name, dtype: object

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:20], s[0:20])
plt.xticks(rotation=90)
plt.show()

# %%
plt.scatter(df['Longitude location of institution'],df['Latitude location of institution'])

# %%
pd.set_option("display.max_columns", 145)
df
# Out:
#       ID number                                               Name  year  \
# 0        100654                           Alabama A & M University  2013
# 1        100663                University of Alabama at Birmingham  2013
# 2        100690                                 Amridge University  2013
# 3        100706                University of Alabama in Huntsville  2013
# 4        100724                           Alabama State University  2013
# 5        100751                          The University of Alabama  2013
# 6        100812                            Athens State University  2013
# 7        100830                    Auburn University at Montgomery  2013
# 8        100858                                  Auburn University  2013
# 9        100937                        Birmingham Southern College  2013
# 10       101073                          Concordia College Alabama  2013
# 11       101189                                Faulkner University  2013
# ...

# %%
w = df['Percent of total enrollment that are women']
a = df['Percent of total enrollment that are Asian']
b = df['Percent of total enrollment that are Black or African American']
h = df['Percent of total enrollment that are Hispanic/Latino']
n = df['Percent of total enrollment that are Native Hawaiian or Other Pacific Islander']
white = df['Percent of total enrollment that are White']
sat = df['Percent of freshmen submitting SAT scores']
act = df['Percent of freshmen submitting ACT scores']
name = df['Name']

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], sat[0:50])
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], act[0:50])
plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], w[0:50])
plt.xticks(rotation=90)
plt.title("Percentagre of Women Accepted")
plt.ylabel("Percentage acceptance")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], a[0:50])
plt.xticks(rotation=90)
plt.title("Percentagre of asian Accepted")
plt.ylabel("Percentage acceptance")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], h[0:50])
plt.xticks(rotation=90)
plt.title("Percentagre of hispanic Accepted")
plt.ylabel("Percentage acceptance")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], n[0:50])
plt.xticks(rotation=90)
plt.title("Percentagre of Pacific Islanders Accepted")
plt.ylabel("Percentage acceptance")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], white[0:50])
plt.xticks(rotation=90)
plt.title("Percentagre of Whites Accepted")
plt.ylabel("Percentage acceptance")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(name[0:50], b[0:50])
plt.xticks(rotation=90)
plt.title("Percentagre of Blacks Accepted")
plt.ylabel("Percentage acceptance")
plt.show()

# %% [markdown]
# One aspect I am noticing for the first 50 colleges (I can do all of them, but the names get all jumbled up, so only the first 50 colleges) is that acceptence rates of the student demographics, specifically with the geography. For example, for the black percentage, the colleges that have the high acceptence rates are usually located around the south east like Alabama, and for Mexicans, it is usually more people located in the states that border Mexico. For woman and whites, there is not much a suprise since 50% of the population is woman, and the largest demographic of people are white.
# I am looking at the geography of where people attend colleges because it seems like there some historical significance as to why certain schools have higher acceptence percentages of different race of people. Perhaps some of unseen variables is the distance a person would travel to attend college. From what I have seen, it is cheaper to attend college in your home state than going out of state (there are even pages on school websites that tell you how much it cost to attend for locals and out-of-state, and out-of-state is usually more expensive. The models created here are straight forward; they show the acceptance rate of the different colleges for different types of people for 50 colleges. I believe that by increasing the scale, it would just reinforce the idea that certain location have certain concentrations of people. For black people, the south west does have histroical significance because back in  the 1700's, slavery was a main part of their economy, and wihle slavery is gone, there is still a lot of black people attending schools in states like Alabama. The same could be said for Mexicans. The parents or grand-parents would migrate to the U.S. and live in one of the border states, resulting in a higher concentratio no Mexicans in the states bordering Mexico.
# I would include more schools to see how the distribution would look like, and by looking at the specific schools and their geography.
